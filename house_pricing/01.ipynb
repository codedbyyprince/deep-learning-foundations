# %%
import tensorflow as tf

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(
 housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
 X_train_full, y_train_full, random_state=42)

# %% [markdown]
# ## Wide and deep neural networks

# %% [markdown]
# ### one input

# %%
normalization_layer = tf.keras.layers.Normalization()

hidden_layer1 = tf.keras.layers.Dense(30, activation="relu")
hidden_layer2 = tf.keras.layers.Dense(30, activation="relu")

concat_layer = tf.keras.layers.Concatenate()
output_layer = tf.keras.layers.Dense(1)

input_ = tf.keras.layers.Input(shape=X_train.shape[1:])

normalized = normalization_layer(input_)

hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)

concat = concat_layer([normalized, hidden2])
output = output_layer(concat)

model = tf.keras.Model(inputs=[input_], outputs=[output])
# Out:
# 2026-04-24 12:31:54.867305: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# ### two inputs

# %%
input_wide = tf.keras.layers.Input(shape=[5]) # features 0 to 4
input_deep = tf.keras.layers.Input(shape=[6]) # features 2 to 7

norm_layer_wide = tf.keras.layers.Normalization()
norm_layer_deep = tf.keras.layers.Normalization()

norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)

hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)

concat = tf.keras.layers.concatenate([norm_wide, hidden2])

output = tf.keras.layers.Dense(1)(concat)

model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=
[output])
# model.fit((X_wide, X_deep), y)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

X_train_wide, X_train_deep = X_train[:, :5], X_train[:, 2:]
X_valid_wide, X_valid_deep = X_valid[:, :5], X_valid[:, 2:]
X_test_wide, X_test_deep = X_test[:, :5], X_test[:, 2:]
X_new_wide, X_new_deep = X_test_wide[:3], X_test_deep[:3]

norm_layer_wide.adapt(X_train_wide)
norm_layer_deep.adapt(X_train_deep)

history = model.fit((X_train_wide, X_train_deep), y_train,
epochs=20,
 validation_data=((X_valid_wide,
X_valid_deep), y_valid))
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - RootMeanSquaredError: 1.0606 - loss: 1.1249 - val_RootMeanSquaredError: 0.8783 - val_loss: 0.7714
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.6827 - loss: 0.4661 - val_RootMeanSquaredError: 0.6577 - val_loss: 0.4326
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.6408 - loss: 0.4106 - val_RootMeanSquaredError: 0.6759 - val_loss: 0.4568
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.6283 - loss: 0.3948 - val_RootMeanSquaredError: 0.8482 - val_loss: 0.7195
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.6193 - loss: 0.3835 - val_RootMeanSquaredError: 0.6118 - val_loss: 0.3743
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.6109 - loss: 0.3733 - val_RootMeanSquaredError: 1.3509 - val_loss: 1.8248
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - RootMeanSquaredError: 0.6107 - loss: 0.3729 - val_RootMeanSquaredError: 1.1679 - val_loss: 1.3641
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.6022 - loss: 0.3627 - val_RootMeanSquaredError: 1.3406 - val_loss: 1.7972
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.6010 - loss: 0.3612 - val_RootMeanSquaredError: 0.7097 - val_loss: 0.5037
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.5987 - loss: 0.3585 - val_RootMeanSquaredError: 1.1544 - val_loss: 1.3326
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5948 - loss: 0.3538 - val_RootMeanSquaredError: 0.6883 - val_loss: 0.4738
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5906 - loss: 0.3488 - val_RootMeanSquaredError: 0.7889 - val_loss: 0.6223
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - RootMeanSquaredError: 0.5826 - loss: 0.3394 - val_RootMeanSquaredError: 0.5711 - val_loss: 0.3262
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5809 - loss: 0.3374 - val_RootMeanSquaredError: 0.5894 - val_loss: 0.3474
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.5836 - loss: 0.3406 - val_RootMeanSquaredError: 0.5625 - val_loss: 0.3164
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5805 - loss: 0.3370 - val_RootMeanSquaredError: 0.6259 - val_loss: 0.3918
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.5757 - loss: 0.3314 - val_RootMeanSquaredError: 0.5596 - val_loss: 0.3131
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5713 - loss: 0.3264 - val_RootMeanSquaredError: 0.9454 - val_loss: 0.8938
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.5735 - loss: 0.3289 - val_RootMeanSquaredError: 1.0938 - val_loss: 1.1965
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5758 - loss: 0.3316 - val_RootMeanSquaredError: 1.2295 - val_loss: 1.5116
